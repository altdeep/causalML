# %% [markdown]
# # Causal Story of E-Commerce Churn out
#
# **Markov Property Validation**
# It assumes that a graph's d-separations represent conditional independence relations in the data. In other words, if two nodes are d-separated in the graph, then they are conditionally independent in the data.

# %%
# Config dict to set the logging level
import logging.config
DEFAULT_LOGGING = {
    'version': 1,
    'disable_existing_loggers': False,
    'loggers': {
        '': {
            'level': 'INFO',
        },
    }
}

logging.config.dictConfig(DEFAULT_LOGGING)
# Disabling warnings output
import warnings
from sklearn.exceptions import DataConversionWarning, ConvergenceWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=ConvergenceWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dowhy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("EComm.csv")

# %%
data.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
data['HighlyDissatisfied'] = data.apply(lambda x: True if(x['SatisfactionScore']<=1) else False, axis = 1)

# %%
data.drop(['CustomerID', 'SatisfactionScore'], axis = 1, inplace = True)
data.dropna(inplace = True)
data.head()
# Out:
#     Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       1     4.0         Mobile Phone         3              6.0
# 3       1     0.0                Phone         3             15.0
# 5       1     0.0             Computer         1             22.0
# 11      1    11.0         Mobile Phone         1              6.0
# 12      1     0.0                Phone         1             11.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0            Debit Card  Female             3.0                         3
# 3            Debit Card    Male             2.0                         4
# 5            Debit Card  Female             3.0                         5
# 11           Debit Card    Male             3.0                         4
# 12                  COD    Male             2.0                         3
#
#       PreferedOrderCat MaritalStatus  NumberOfAddress  Complain  \
# 0   Laptop & Accessory        Single                9         1
# 3   Laptop & Accessory        Single                8         0
# 5         Mobile Phone        Single                2         1
# 11             Fashion        Single               10         1
# 12              Mobile        Single                2         1
#
#     OrderAmountHikeFromlastYear  CouponUsed  OrderCount  DaySinceLastOrder  \
# 0                          11.0         1.0         1.0                5.0
# 3                          23.0         0.0         1.0                3.0
# 5                          22.0         4.0         6.0                7.0
# 11                         13.0         0.0         1.0                0.0
# 12                         13.0         2.0         2.0                2.0
#
#     CashbackAmount  HighlyDissatisfied
# 0              160               False
# 3              134               False
# 5              139               False
# 11             154               False
# 12             134               False

# %%
import pandas as pd
import numpy as np
from pgmpy.base.DAG import DAG
from pgmpy.estimators.CITests import chi_square
from pgmpy.independencies import IndependenceAssertion

# Build the causal DAG.
G = DAG()
G.add_edges_from(
    [
      ('HighlyDissatisfied', 'Churn'),
    ('Complain', 'Churn'),
    ('Complain', 'HighlyDissatisfied'),
    ('DaySinceLastOrder', 'Churn'),
    ('DaySinceLastOrder', 'OrderCount'),
    ('CityTier', 'OrderCount'),
    ('CouponUsed', 'OrderCount'),
    ('CouponUsed', 'OrderAmountHikeFromlastYear'),
    ('OrderCount', 'OrderAmountHikeFromlastYear'),
    ('OrderAmountHikeFromlastYear', 'Churn'),
    ('Tenure', 'OrderAmountHikeFromlastYear'),
    ('WarehouseToHome', 'CityTier'),
#     ('CashBackAmount', 'OrderCount'),
    ('PreferredLoginDevice', 'HourSpendOnApp'),
    ('HourSpendOnApp', 'OrderCount'),
    ('NumberOfAddress', 'NumberOfDeviceRegistered'),
    ('NumberOfDeviceRegistered', 'OrderCount'),
    ]
)

# List D-Separations
dseps = G.get_independencies()
# print(dseps)

# %%
# %%time
# Run Chi-squared tests for independence
significance = .05

def test_dsep(dsep: IndependenceAssertion):
    test_outputs = []
    for X in list(dsep.get_assertion()[0]):
        for Y in list(dsep.get_assertion()[1]):
            Z = list(dsep.get_assertion()[2])
            test_result = chi_square(X=X, Y=Y, Z=Z, data=data, boolean=True, significance_level=significance)
            test_outputs.append((IndependenceAssertion(X, Y, Z), test_result))
    return test_outputs

results = [test_dsep(dsep) for dsep in dseps.get_assertions()]
results_flat = [item for sublist in results for item in sublist]
results = {k: v for k, v in results_flat}

# Hint on how to count the number of Trues.
sum(results.values()), len(results)
# Out:
# CPU times: user 1h 19min 21s, sys: 10.3 s, total: 1h 19min 31s
# Wall time: 1h 19min 27s
# (14701, 151360)

# %% [markdown]
# ### Checking the results where the chi-square test returns true.
# If test results are true: the two d-seperated variables are independent
# else: they are related

# %%
tocheck = []
for key,value in results.items():
    if value:
        print(key)
    else:
        tocheck.append(key)
# Out:
# (OrderCount ⟂ Tenure)
# (OrderCount ⟂ Complain)
# (OrderCount ⟂ HighlyDissatisfied)
# (OrderCount ⟂ Complain | Tenure)
# (OrderCount ⟂ Tenure | DaySinceLastOrder)
# (OrderCount ⟂ Complain | DaySinceLastOrder)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered)
# (OrderCount ⟂ Tenure | Complain)
# (OrderCount ⟂ Tenure | HourSpendOnApp)
# (OrderCount ⟂ Complain | HourSpendOnApp)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp)
# (OrderCount ⟂ Tenure | HighlyDissatisfied)
# (OrderCount ⟂ Complain | HighlyDissatisfied)
# (OrderCount ⟂ Tenure | NumberOfAddress)
# (OrderCount ⟂ Complain | NumberOfAddress)
# (OrderCount ⟂ Tenure | CityTier)
# (OrderCount ⟂ Complain | CityTier)
# (OrderCount ⟂ WarehouseToHome | CityTier)
# (OrderCount ⟂ Tenure | WarehouseToHome)
# (OrderCount ⟂ Complain | WarehouseToHome)
# (OrderCount ⟂ Tenure | PreferredLoginDevice)
# (OrderCount ⟂ Complain | PreferredLoginDevice)
# (OrderCount ⟂ Tenure | CouponUsed)
# (OrderCount ⟂ Complain | CouponUsed)
# (OrderCount ⟂ Complain | Tenure, HourSpendOnApp)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp)
# (OrderCount ⟂ Complain | Tenure, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier)
# (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp)
# (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp)
# (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, HighlyDissatisfied)
# (OrderCount ⟂ Complain | DaySinceLastOrder, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, NumberOfAddress)
# (OrderCount ⟂ Complain | DaySinceLastOrder, NumberOfAddress)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, NumberOfAddress)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp)
# (OrderCount ⟂ Tenure | Complain, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, CityTier)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier)
# (OrderCount ⟂ Tenure | Complain, WarehouseToHome)
# (OrderCount ⟂ Tenure | Complain, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | Complain, CouponUsed)
# (OrderCount ⟂ Tenure | HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Complain | HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Complain | HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier)
# (OrderCount ⟂ Complain | HourSpendOnApp, CityTier)
# (OrderCount ⟂ Tenure | HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Tenure | HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Complain | HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | CityTier, OrderAmountHikeFromlastYear)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfAddress)
# (OrderCount ⟂ Tenure | CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Complain | CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Complain | WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Complain | PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, CouponUsed)
# (OrderCount ⟂ Tenure | CityTier, NumberOfAddress)
# (OrderCount ⟂ Complain | CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Complain | PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | CityTier, WarehouseToHome)
# (OrderCount ⟂ Tenure | CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier)
# (OrderCount ⟂ Tenure | CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | CityTier, CouponUsed)
# (OrderCount ⟂ Tenure | WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier)
# (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Churn, HourSpendOnApp)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, CityTier)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, CouponUsed)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Churn, DaySinceLastOrder, HourSpendOnApp)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, DaySinceLastOrder, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, DaySinceLastOrder, NumberOfAddress)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, DaySinceLastOrder, CouponUsed)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, Churn)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HourSpendOnApp)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, Churn)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, OrderAmountHikeFromlastYear)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, CityTier, WarehouseToHome)
# (OrderCount ⟂ Tenure | Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, Churn)
# (OrderCount ⟂ Tenure | Complain, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfAddress, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Churn, HourSpendOnApp, CityTier)
# (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Tenure | HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | CityTier, OrderAmountHikeFromlastYear, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, OrderAmountHikeFromlastYear)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CityTier, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | CityTier, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, CityTier, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | CityTier, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, NumberOfDeviceRegistered, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier, Churn)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, HighlyDissatisfied, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Churn, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Churn, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Churn, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Churn, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, HighlyDissatisfied, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, HighlyDissatisfied, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Tenure, Churn, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, DaySinceLastOrder, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Churn, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Churn, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, DaySinceLastOrder, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HourSpendOnApp, Churn)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, Churn, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, Complain, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, CityTier, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CityTier, WarehouseToHome)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfDeviceRegistered, CityTier, Churn)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CityTier, Churn)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, Churn, WarehouseToHome)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, PreferredLoginDevice, Churn)
# (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, Churn, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Churn, NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Churn, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, PreferredLoginDevice, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | HighlyDissatisfied, Churn, NumberOfDeviceRegistered, CouponUsed)
# (OrderCount ⟂ Tenure | NumberOfAddress, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | NumberOfAddress, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | NumberOfAddress, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfDeviceRegistered, CityTier, NumberOfAddress)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, CityTier, WarehouseToHome)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, CityTier, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, CityTier, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, Complain, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, Complain, HourSpendOnApp, Churn)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, Complain, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, NumberOfAddress, HourSpendOnApp, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Complain, NumberOfAddress, HourSpendOnApp, Churn)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier, Churn)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, WarehouseToHome, Churn)
# (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, Churn, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, OrderAmountHikeFromlastYear, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, OrderAmountHikeFromlastYear, Churn)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Complain, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Tenure | Complain, CityTier, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Complain, CityTier, Churn)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Complain, CityTier, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, Complain, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ Tenure | Complain, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Complain, NumberOfAddress, CityTier, Churn)
# (OrderCount ⟂ Tenure | Complain, CityTier, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ WarehouseToHome | Complain, CityTier, Churn, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, Churn, HourSpendOnApp, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ WarehouseToHome | Churn, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, HourSpendOnApp, CouponUsed, PreferredLoginDevice)
# (OrderCount ⟂ Complain | HighlyDissatisfied, HourSpendOnApp, CouponUsed, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | HighlyDissatisfied, Churn, HourSpendOnApp, CouponUsed)
# (OrderCount ⟂ Tenure | NumberOfAddress, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | NumberOfAddress, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Churn, HourSpendOnApp, CityTier, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | Churn, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Churn, HourSpendOnApp, CityTier, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Churn, CityTier, OrderAmountHikeFromlastYear, HighlyDissatisfied)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CityTier, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ Complain | HighlyDissatisfied, CityTier, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, CityTier, PreferredLoginDevice, NumberOfAddress)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Churn, CityTier, NumberOfAddress)
# (OrderCount ⟂ Tenure | HighlyDissatisfied, CityTier, WarehouseToHome, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Churn, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | HighlyDissatisfied, Churn, CityTier, CouponUsed)
# (OrderCount ⟂ WarehouseToHome | Churn, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, Complain, HourSpendOnApp, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, Complain, HighlyDissatisfied, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, Complain, NumberOfAddress, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, Complain, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, Complain, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, NumberOfAddress, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HighlyDissatisfied, NumberOfAddress, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, HighlyDissatisfied, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, NumberOfAddress, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfDeviceRegistered, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HourSpendOnApp, NumberOfAddress, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, NumberOfAddress, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, NumberOfAddress, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HourSpendOnApp, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HourSpendOnApp, CityTier, Churn)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, HourSpendOnApp, WarehouseToHome, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HighlyDissatisfied, NumberOfAddress, CityTier)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, HighlyDissatisfied, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, NumberOfAddress, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, Complain, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, CityTier)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, NumberOfAddress, CityTier, Churn)
# (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, NumberOfAddress, WarehouseToHome, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HourSpendOnApp, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HighlyDissatisfied, NumberOfAddress, CityTier, PreferredLoginDevice)
# (OrderCount ⟂ WarehouseToHome | Tenure, HighlyDissatisfied, NumberOfAddress, CityTier, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, HighlyDissatisfied, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfAddress, CityTier, PreferredLoginDevice, Churn)
# (OrderCount ⟂ Tenure | DaySinceLastOrder, Complain, HighlyDissatisfied, PreferredLoginDevice, CouponUsed)
# (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, PreferredLoginDevice)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, Churn)
# (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, CouponUsed)
# (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Complain, HourSpendOnApp, HighlyDissatisfied, CouponUsed)
# ...
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, CityTier, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Churn, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Churn, HourSpendOnApp, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Churn, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Churn, HourSpendOnApp, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, CityTier, HighlyDissatisfied, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, WarehouseToHome, HighlyDissatisfied, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered)
# (PreferredLoginDevice ⟂ CouponUsed | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, DaySinceLastOrder, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, NumberOfDeviceRegistered, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | NumberOfDeviceRegistered, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, Complain, HourSpendOnApp, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, Complain, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, NumberOfAddress, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, Complain, CityTier, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, Complain, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | HighlyDissatisfied, Churn, HourSpendOnApp, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, HourSpendOnApp, CityTier, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, HourSpendOnApp, WarehouseToHome, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Churn, HourSpendOnApp, WarehouseToHome, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Complain, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Complain, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, NumberOfAddress, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, NumberOfAddress, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HighlyDissatisfied, NumberOfAddress, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HighlyDissatisfied, NumberOfAddress, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | Tenure, Complain, HourSpendOnApp, HighlyDissatisfied, NumberOfAddress, WarehouseToHome, Churn)
# (PreferredLoginDevice ⟂ CouponUsed | OrderCount, Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HourSpendOnApp, HighlyDissatisfied, CityTier, Churn)

# %%
tocheck
# Out:
# [(OrderCount ⟂ HighlyDissatisfied | Tenure),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp),
#  (OrderCount ⟂ Complain | OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp),
#  (OrderCount ⟂ Complain | Tenure, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CouponUsed),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CouponUsed),
#  (OrderCount ⟂ Complain | HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ WarehouseToHome | Tenure, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, Complain, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, CityTier),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, CityTier),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, WarehouseToHome),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, WarehouseToHome),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, PreferredLoginDevice),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, PreferredLoginDevice),
#  (OrderCount ⟂ NumberOfAddress | Tenure, Churn, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | Tenure, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, HighlyDissatisfied, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, HighlyDissatisfied, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, WarehouseToHome),
#  (OrderCount ⟂ Complain | Tenure, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, CityTier, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Churn, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ PreferredLoginDevice | Complain, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ Churn | Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ WarehouseToHome | Complain, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Churn, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Churn, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfAddress, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, WarehouseToHome),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, WarehouseToHome),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ WarehouseToHome | Churn, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | Complain, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | Complain, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Tenure | Complain, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ NumberOfAddress | Churn, NumberOfDeviceRegistered, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfAddress, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | Complain, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, CityTier),
#  (OrderCount ⟂ Tenure | Complain, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, PreferredLoginDevice, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | Complain, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, PreferredLoginDevice, NumberOfAddress),
#  (OrderCount ⟂ Tenure | Complain, NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, NumberOfAddress, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | Complain, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, PreferredLoginDevice, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Complain | HourSpendOnApp, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ WarehouseToHome | HourSpendOnApp, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | HourSpendOnApp, OrderAmountHikeFromlastYear, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, OrderAmountHikeFromlastYear, PreferredLoginDevice),
#  (OrderCount ⟂ PreferredLoginDevice | Churn, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | HourSpendOnApp, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | HourSpendOnApp, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfAddress, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ Tenure | NumberOfAddress, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfAddress, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Tenure | HourSpendOnApp, CityTier, WarehouseToHome),
#  (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, WarehouseToHome),
#  (OrderCount ⟂ PreferredLoginDevice | HourSpendOnApp, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | HourSpendOnApp, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | HourSpendOnApp, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | HourSpendOnApp, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | HourSpendOnApp, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | CityTier, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | WarehouseToHome, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | CityTier, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ WarehouseToHome | CityTier, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfAddress, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | CityTier, OrderAmountHikeFromlastYear, PreferredLoginDevice),
#  (OrderCount ⟂ WarehouseToHome | CityTier, OrderAmountHikeFromlastYear, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, OrderAmountHikeFromlastYear, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | WarehouseToHome, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | WarehouseToHome, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Tenure | HighlyDissatisfied, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Tenure | HighlyDissatisfied, CouponUsed, NumberOfAddress),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, CouponUsed, NumberOfAddress),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | HighlyDissatisfied, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | PreferredLoginDevice, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | CityTier, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Tenure | NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ Tenure | PreferredLoginDevice, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfAddress, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Tenure | NumberOfAddress, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfAddress, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfAddress, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Tenure | CityTier, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | CityTier, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Tenure | CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Complain | CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Tenure | PreferredLoginDevice, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | PreferredLoginDevice, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | PreferredLoginDevice, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, Complain, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ WarehouseToHome | Tenure, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Tenure, Churn, DaySinceLastOrder, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | Tenure, DaySinceLastOrder, NumberOfDeviceRegistered, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, Complain, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, HourSpendOnApp),
#  (OrderCount ⟂ Churn | Tenure, Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ WarehouseToHome | Tenure, Complain, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, CityTier),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, WarehouseToHome),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, Complain, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ PreferredLoginDevice | Tenure, DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Churn | Tenure, DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied),
# ...
#  (OrderCount ⟂ Complain | Tenure, CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, WarehouseToHome, OrderAmountHikeFromlastYear),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, WarehouseToHome, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, HighlyDissatisfied, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, HighlyDissatisfied, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, HighlyDissatisfied, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, CouponUsed, HighlyDissatisfied, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, CityTier, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, CityTier, HighlyDissatisfied, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, CityTier, HighlyDissatisfied, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, HighlyDissatisfied, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | Tenure, WarehouseToHome, HighlyDissatisfied, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, HighlyDissatisfied, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress, CityTier, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, NumberOfAddress, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, NumberOfAddress, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, WarehouseToHome, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | Tenure, CityTier, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, CityTier, PreferredLoginDevice, CouponUsed),
#  (OrderCount ⟂ WarehouseToHome | Tenure, Churn, CityTier, CouponUsed),
#  (OrderCount ⟂ Complain | Tenure, PreferredLoginDevice, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | Tenure, PreferredLoginDevice, WarehouseToHome, CouponUsed),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | Complain, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, NumberOfAddress),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ WarehouseToHome | Complain, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | Complain, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Complain, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, PreferredLoginDevice, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Complain, DaySinceLastOrder, Churn, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Complain, DaySinceLastOrder, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, NumberOfAddress),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, CityTier, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ PreferredLoginDevice | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, HourSpendOnApp, WarehouseToHome, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, PreferredLoginDevice),
#  (OrderCount ⟂ PreferredLoginDevice | Churn, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Churn, DaySinceLastOrder, HourSpendOnApp, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ PreferredLoginDevice | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, HourSpendOnApp, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Churn | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ Churn | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfAddress),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ WarehouseToHome | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, CityTier, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, WarehouseToHome, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Churn | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | DaySinceLastOrder, PreferredLoginDevice, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | Churn, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ Complain | Churn, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ NumberOfAddress | Churn, DaySinceLastOrder, OrderAmountHikeFromlastYear, NumberOfDeviceRegistered),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Churn | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, OrderAmountHikeFromlastYear, CouponUsed),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, NumberOfAddress, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, NumberOfAddress, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, PreferredLoginDevice, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, Churn, DaySinceLastOrder, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed, HighlyDissatisfied),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed, HighlyDissatisfied),
#  (OrderCount ⟂ NumberOfAddress | NumberOfDeviceRegistered, DaySinceLastOrder, CouponUsed, HighlyDissatisfied),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ WarehouseToHome | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, CityTier, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Complain | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ HighlyDissatisfied | NumberOfDeviceRegistered, DaySinceLastOrder, WarehouseToHome, NumberOfAddress),
#  (OrderCount ⟂ Tenure | NumberOfDeviceRegistered, DaySinceLastOrder, PreferredLoginDevice, NumberOfAddress),
#  ...]

# %%
import csv
with open('results.csv', 'w') as f:
    for key in results.keys():
        f.write("%s,%s\n"%(key,my_dict[key]))

# %% [markdown]
# ### Conclusions:
#
# *On checking the chi-square results for the d-seperated pair of nodes, we concluded that the generated causal graph doesn't have any conflict.*
