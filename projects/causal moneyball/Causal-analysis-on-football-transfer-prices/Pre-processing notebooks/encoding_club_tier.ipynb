# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from fuzzywuzzy import fuzz
from tqdm import tqdm

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv('../transfers1.4.csv')
df.head()
# Out:
#    Unnamed: 0    ID         to_club_name  to_league_name        player_name  \
# 0        3812  3813           Hertha BSC    1 Bundesliga      Lukas Klünter
# 1        4460  4461        Dinamo Moscow    Premier Liga  Konstantin Rausch
# 2        4596  4597            Fulham FC  Premier League     Sascha Riether
# 3        1818  1819    Tottenham Hotspur  Premier League       Kevin Wimmer
# 4        3017  3018  TSG 1899 Hoffenheim    1 Bundesliga         Kevin Vogt
#
#    age     position from_club_involved_name     fee transfer_movement  \
# 0   22   Right Back              1. FC Köln  £1.80m                in
# 1   27    Left Back              1. FC Köln  £1.35m                in
# 2   30   Right Back              1. FC Köln  £1.26m                in
# 3   22  Centre Back              1. FC Köln  £5.40m                in
# 4   24  Centre Back              1. FC Köln  £2.70m                in
#
#    fee_cleaned  year     season grouping_positions_1 grouping_positions_2  \
# 0         1.80  2018  2018/2019                   RB                    B
# 1         1.35  2017  2017/2018                   LB                    B
# 2         1.26  2013  2013/2014                   RB                    B
# 3         5.40  2015  2015/2016                   CB                    D
# 4         2.70  2016  2016/2017                   CB                    D
#
#   normalized_from_club_name   from_league
# 0                1. FC Köln  1 Bundesliga
# 1                1. FC Köln  1 Bundesliga
# 2                1. FC Köln  1 Bundesliga
# 3                1. FC Köln  1 Bundesliga
# 4                1. FC Köln  1 Bundesliga

# %%
for i in range(len(df)):
    if(df.normalized_from_club_name[i] == "0"):
        df.normalized_from_club_name[i] = df.from_club_involved_name[i]

# %% [markdown]
# #### Grouping based on spending power of club

# %%
club_spend = df.groupby('to_club_name')['fee_cleaned'].sum()
club_spend = pd.DataFrame(club_spend)
club_spend = club_spend.sort_values(by=['fee_cleaned'], ascending=False)
club_spend = club_spend.reset_index()
club_spend = club_spend.rename(columns = {'to_club_name': 'club_name', 'fee_cleaned' : 'fee_spent'})
club_spend.head(20)
# Out:
#               club_name  fee_spent
# 0       Manchester City   1504.897
# 1          FC Barcelona   1331.170
# 2           Real Madrid   1226.930
# 3            Chelsea FC   1213.760
# 4           Juventus FC   1180.153
# 5   Paris Saint-Germain   1141.740
# 6     Manchester United   1117.300
# 7          Liverpool FC    937.598
# 8       Atlético Madrid    905.735
# 9            Arsenal FC    762.081
# 10             AC Milan    713.765
# 11            AS Monaco    685.900
# 12              AS Roma    652.870
# 13        Bayern Munich    650.880
# 14           SSC Napoli    629.561
# 15    Tottenham Hotspur    621.010
# 16           Everton FC    600.635
# 17    Borussia Dortmund    572.963
# 18          Inter Milan    535.060
# 19          Valencia CF    529.678

# %%
club_earned = df.groupby('normalized_from_club_name')['fee_cleaned'].sum()
club_earned = pd.DataFrame(club_earned)
club_earned = club_earned.sort_values(by=['fee_cleaned'], ascending=False)
club_earned = club_earned.reset_index()
club_earned = club_earned.rename(columns = {'normalized_from_club_name': 'club_name', 'fee_cleaned' : 'fee_earned'})
club_earned.head(20)
# Out:
#             club_name  fee_earned
# 0     Atlético Madrid     820.450
# 1           AS Monaco     802.335
# 2          SL Benfica     728.470
# 3         Real Madrid     701.550
# 4         Juventus FC     690.653
# 5        FC Barcelona     681.450
# 6             AS Roma     641.075
# 7        Liverpool FC     628.580
# 8            FC Porto     621.640
# 9          Chelsea FC     614.694
# 10  Borussia Dortmund     590.833
# 11         Sevilla FC     506.080
# 12  Tottenham Hotspur     471.237
# 13        Inter Milan     468.282
# 14        Valencia CF     465.355
# 15     Ajax Amsterdam     461.410
# 16          Genoa CFC     459.815
# 17     Olympique Lyon     455.140
# 18    Manchester City     421.885
# 19         LOSC Lille     399.390

# %% [markdown]
# #### net spend dataframe

# %%
club_net_spend = pd.merge(club_spend, club_earned, how = 'outer', on = 'club_name')
club_net_spend = club_net_spend.fillna(0)
club_net_spend['net_spend'] = club_net_spend['fee_spent'] - club_net_spend['fee_earned']
club_net_spend = club_net_spend.sort_values(by=['net_spend'], ascending=False)

# %%
club_net_spend = club_net_spend.sort_values(by=['fee_spent'], ascending=False)
club_net_spend.fee_spent.describe()
# Out:
# count     999.000000
# mean       36.251253
# std       142.246165
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1504.897000
# Name: fee_spent, dtype: float64

# %%
club_net_spend.describe()
# Out:
#          fee_spent  fee_earned     net_spend
# count   999.000000  999.000000  9.990000e+02
# mean     36.251253   36.251253  4.552026e-16
# std     142.246165   99.008833  7.678126e+01
# min       0.000000    0.000000 -3.869510e+02
# 25%       0.000000    0.630000 -8.681000e+00
# 50%       0.000000    2.930000 -2.030000e+00
# 75%       0.000000   16.790000 -3.240000e-01
# max    1504.897000  820.450000  1.083012e+03

# %% [markdown]
# #### CLassifying into 4 tiers
#  - Tier 1 : Clubs that spent more than 300M Euros
#  - Tier 2 : Clubs that spent more than 100M Euros but less than 300M Eruos
#  - Tier 3 : Clubs that spent more than 20M Euros but less than 100M Euros
#  - Tier 4 : CLubs that spent less than 20M Euros

# %%
club_net_spend['Tier'] = 0
for i in range(len(club_net_spend)):
    if(club_net_spend.fee_spent[i] >= 300 ):
        club_net_spend['Tier'][i] = 'Tier_1'
    elif((300 > club_net_spend.fee_spent[i]) and (club_net_spend.fee_spent[i] >= 100)):
        club_net_spend['Tier'][i] = 'Tier_2'
    elif((100 > club_net_spend.fee_spent[i]) and (club_net_spend.fee_spent[i] >= 20)):
        club_net_spend['Tier'][i] = 'Tier_3'
    else:
        club_net_spend['Tier'][i] = 'Tier_4'
        
club_net_spend['Tier'].value_counts()
# Out:
# Tier_4    855
# Tier_3     56
# Tier_2     52
# Tier_1     36
# Name: Tier, dtype: int64

# %%
club_net_spend
# Out:
#            club_name  fee_spent  fee_earned  net_spend    Tier
# 0    Manchester City   1504.897     421.885   1083.012  Tier_1
# 1       FC Barcelona   1331.170     681.450    649.720  Tier_1
# 2        Real Madrid   1226.930     701.550    525.380  Tier_1
# 3         Chelsea FC   1213.760     614.694    599.066  Tier_1
# 4        Juventus FC   1180.153     690.653    489.500  Tier_1
# ..               ...        ...         ...        ...     ...
# 717      Bologna U19      0.000       0.900     -0.900  Tier_4
# 702         Ajax U21      0.000       0.946     -0.946  Tier_4
# 701    SV Sandhausen      0.000       0.990     -0.990  Tier_4
# 700      Pol. Warsaw      0.000       0.990     -0.990  Tier_4
# 609         Vozdovac      0.000       2.030     -2.030  Tier_4
#
# [999 rows x 5 columns]

# %%
#encoding to_club_tiers
incoming_tiers = club_net_spend.rename(columns ={'club_name':'to_club_name','Tier':'to_club_tier'})
df_1 = pd.merge(df, incoming_tiers, how = 'outer', on = 'to_club_name')
df_1 = df_1.drop(columns = ['fee_spent','fee_earned','net_spend'])
df_1 = df_1.dropna(subset=['age', 'position'])
df_1.to_club_tier.value_counts()
# Out:
# Tier_2    2447
# Tier_1    2242
# Tier_3    1370
# Tier_4     675
# Name: to_club_tier, dtype: int64

# %%
#encoding from_club_tiers
outgoing_tiers = club_net_spend.rename(columns ={'club_name':'normalized_from_club_name','Tier':'from_club_tier'})
df_2 = pd.merge(df_1, outgoing_tiers, how = 'outer', on = 'normalized_from_club_name')
df_2 = df_2.drop(columns = ['fee_spent','fee_earned','net_spend'])
df_2 = df_2.dropna(subset=['age', 'position'])
df_2.from_club_tier.value_counts()
# Out:
# Tier_4    3107
# Tier_1    1508
# Tier_2    1231
# Tier_3     888
# Name: from_club_tier, dtype: int64

# %%
df_2
# Out:
#       Unnamed: 0      ID         to_club_name    to_league_name  \
# 0         3812.0  3813.0           Hertha BSC      1 Bundesliga
# 1         4460.0  4461.0        Dinamo Moscow      Premier Liga
# 2         4596.0  4597.0            Fulham FC    Premier League
# 3         1818.0  1819.0    Tottenham Hotspur    Premier League
# 4         3017.0  3018.0  TSG 1899 Hoffenheim      1 Bundesliga
# ...          ...     ...                  ...               ...
# 6729      5808.0  5809.0     Mordovia Saransk      Premier Liga
# 6730      6505.0  6506.0    Académica Coimbra          Liga Nos
# 6731      6577.0  6578.0            NAC Breda        Eredivisie
# 6732      6682.0  6683.0           Leixões SC          Liga Nos
# 6733      6221.0  6222.0          CD Tenerife  Primera Division
#
#             player_name   age            position from_club_involved_name  \
# 0         Lukas Klünter  22.0          Right Back              1. FC Köln
# 1     Konstantin Rausch  27.0           Left Back              1. FC Köln
# 2        Sascha Riether  30.0          Right Back              1. FC Köln
# 3          Kevin Wimmer  22.0         Centre Back              1. FC Köln
# 4            Kevin Vogt  24.0         Centre Back              1. FC Köln
# ...                 ...   ...                 ...                     ...
# 6729    Milan Perendija  27.0         Centre Back           Otelul Galati
# 6730         Rafa Lopes  22.0      Centre Forward                Penafiel
# 6731         Karol Mets  24.0         Centre Back               Viking FK
# 6732               Cauê  20.0  Defensive Midfield             Santo André
# 6733      Ezequiel Luna  22.0         Centre Back            Tiro Federal
#
#          fee transfer_movement  fee_cleaned    year     season  \
# 0     £1.80m                in        1.800  2018.0  2018/2019
# 1     £1.35m                in        1.350  2017.0  2017/2018
# 2     £1.26m                in        1.260  2013.0  2013/2014
# 3     £5.40m                in        5.400  2015.0  2015/2016
# 4     £2.70m                in        2.700  2016.0  2016/2017
# ...      ...               ...          ...     ...        ...
# 6729   £450k                in        0.450  2012.0  2012/2013
# 6730   £135k                in        0.135  2013.0  2013/2014
# 6731    £90k                in        0.090  2017.0  2017/2018
# 6732    £45k                in        0.045  2009.0  2009/2010
# 6733   £270k                in        0.270  2009.0  2009/2010
#
#      grouping_positions_1 grouping_positions_2 normalized_from_club_name  \
# 0                      RB                    B                1. FC Köln
# 1                      LB                    B                1. FC Köln
# 2                      RB                    B                1. FC Köln
# 3                      CB                    D                1. FC Köln
# 4                      CB                    D                1. FC Köln
# ...                   ...                  ...                       ...
# 6729                   CB                    D             Otelul Galati
# 6730                   CF                    F                  Penafiel
# 6731                   CB                    D                 Viking FK
# 6732                  CDM                    M               Santo André
# 6733                   CB                    D              Tiro Federal
#
#        from_league to_club_tier from_club_tier
# 0     1 Bundesliga       Tier_3         Tier_3
# 1     1 Bundesliga       Tier_2         Tier_3
# 2     1 Bundesliga       Tier_2         Tier_3
# 3     1 Bundesliga       Tier_1         Tier_3
# 4     1 Bundesliga       Tier_2         Tier_3
# ...            ...          ...            ...
# 6729         Other       Tier_4         Tier_4
# 6730         Other       Tier_4         Tier_4
# 6731         Other       Tier_4         Tier_4
# 6732         Other       Tier_4         Tier_4
# 6733         Other       Tier_4         Tier_4
#
# [6734 rows x 19 columns]

# %%
df_2.to_csv('../transfers1.5.csv')
